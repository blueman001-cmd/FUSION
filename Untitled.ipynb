# %%
reentrancy (RE), timestamp(TD),
integeroverflow(OF), delegatecall (DE),

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 模型名称（按列顺序）
models = [
    "Scheck", "Osiris", "Slither", "Mythril", "sFuzz", "Confuz", "SaferSC",
    "Escort", "SCGCN", "IVD", "TMP", "CGE", "AME", "SMS", "FUSION"
]

# 正确替换后的各指标的Avg数据
accuracy = [54.68, 63.99, 70.50, 67.24, 44.34, 68.47, 68.20, 65.88, 70.60, 69.63, 74.33, 75.59, 77.35, 82.95, 92.57]
recall =    [55.11, 51.16, 64.31, 62.46, 28.79, 67.75, 68.40, 68.87, 72.85, 71.86, 72.81, 73.87, 74.93, 78.81, 87.32]
precision = [45.49, 53.68, 71.28, 57.55, 29.63, 62.23, 68.70, 66.77, 71.98, 71.69, 73.29, 74.48, 75.66, 80.93, 91.58]
f1_score =  [46.71, 50.32, 67.35, 58.28, 28.94, 60.16, 69.02, 67.40, 72.41, 71.53, 73.04, 74.17, 75.29, 79.83, 89.27]

# 创建 DataFrame
df = pd.DataFrame({
    "Model": models,
    "Accuracy": accuracy,
    "Recall": recall,
    "Precision": precision,
    "F1-score": f1_score
})

# 绘图
plt.figure(figsize=(16, 6))
plt.plot(df["Model"], df["Accuracy"], marker='o', label='Accuracy')
plt.plot(df["Model"], df["Recall"], marker='s', label='Recall')
plt.plot(df["Model"], df["Precision"], marker='^', label='Precision')
plt.plot(df["Model"], df["F1-score"], marker='d', label='F1-score')

# 设置图表属性
plt.title("Average Performance Comparison")
plt.xlabel("Models")
plt.ylabel("Value (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()

plt.savefig("avg_comparison.jpg", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 模型名称
models = ['rem-ms', 'rem-gat', 'rem-gru', 'all']

# 对应的 Avg 值（从你提供的表格中填入）
accuracy = [89.19, 87.57, 87.95, 92.57]
recall =    [79.80, 76.71, 78.52, 87.82]
precision = [88.54, 89.49, 89.82, 91.58]
f1_score =  [83.47, 80.39, 82.22, 89.27]

# 创建 DataFrame（方便绘图）
df = pd.DataFrame({
    'Model': models,
    'Accuracy': accuracy,
    'Recall': recall,
    'Precision': precision,
    'F1-score': f1_score
})

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(df['Model'], df['Accuracy'], marker='o', label='Accuracy')
plt.plot(df['Model'], df['Recall'], marker='s', label='Recall')
plt.plot(df['Model'], df['Precision'], marker='^', label='Precision')
plt.plot(df['Model'], df['F1-score'], marker='d', label='F1-score')

# 美化图表
plt.title('Average Performance Comparison of Ablation Experiment ')
plt.xlabel('Model')
plt.ylabel('Value (%)')
plt.ylim(70, 100)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()

plt.savefig("avg_comparison_ablation.jpg", dpi=300)
# 显示图
plt.show()

# %%
import matplotlib.pyplot as plt

# 模型名称
models = [
    "32-hid", "64-hid", "128-hid", "256-hid", "512-hid",
    "1-layer", "2-layer", "3-layer", "4-layer", "5-layer"
]

# 平均指标数据（从 LaTeX 表格中提取的 Avg 行数据）
accuracy = [90.35, 88.92, 88.92, 89.28, 89.28, 88.92, 90.58, 91.04, 91.18, 90.54]
recall   = [78.68, 77.14, 83.14, 83.43, 81.87, 79.80, 83.85, 85.24, 84.55, 87.28]
precision= [94.57, 91.78, 86.10, 86.89, 89.36, 88.22, 89.49, 89.59, 89.93, 87.37]
f1_score = [84.54, 82.48, 84.35, 84.92, 84.13, 83.46, 86.24, 87.09, 86.83, 87.18]

# 创建图形
plt.figure(figsize=(12, 6))

# 画每条线
plt.plot(models, accuracy,  marker='o', label='Accuracy')
plt.plot(models, recall,    marker='s', label='Recall')
plt.plot(models, precision, marker='^', label='Precision')
plt.plot(models, f1_score,  marker='d', label='F1-score')

# 图形修饰
plt.title('Comparison of Parameter Sensitivity Experiment Results')
plt.xlabel('Model ')
plt.ylabel('Value (%)')
plt.ylim(75, 95)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.xticks(rotation=45)

# 展示图
plt.tight_layout()

plt.savefig("avg_comparison_ps.jpg", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据来自表格的 Avg 行
methods = ['rem-ms', 'rem-gat', 'rem-gru', 'all', 'lstm', 'gru', 'gcn', 'sage', 'gat', 'att', 'sum']
A = [89.19, 87.57, 87.95, 92.75, 91.04, 92.75, 89.28, 89.01, 92.75, 90.95, 92.75]  # Accuracy
R = [79.80, 76.71, 78.52, 87.32, 84.92, 87.32, 81.07, 84.96, 87.32, 81.91, 87.32]  # Recall
P = [88.54, 89.49, 89.82, 91.58, 89.55, 91.58, 88.70, 85.80, 91.58, 91.50, 91.58]  # Precision
F = [83.47, 80.39, 82.22, 89.27, 86.88, 89.27, 84.08, 84.85, 89.27, 85.99, 89.27]  # F1-score

# 设置浅色调风格
plt.style.use('seaborn-v0_8-pastel')  # 使用 seaborn 的浅色调风格
plt.figure(figsize=(12, 6))

# 绘制折线图，设置粗线
plt.plot(methods, A, label='Accuracy', linewidth=3, marker='o', markersize=8, color='#66b3ff')
plt.plot(methods, R, label='Recall', linewidth=3, marker='s', markersize=8, color='#ff9999')
plt.plot(methods, P, label='Precision', linewidth=3, marker='^', markersize=8, color='#99ff99')
plt.plot(methods, F, label='F1-score', linewidth=3, marker='d', markersize=8, color='#ffcc99')

# 设置图表标题和标签
plt.title('Comparison of Average Metrics Across Methods', fontsize=16, pad=15)
plt.xlabel('Methods', fontsize=12)
plt.ylabel('Percentage (%)', fontsize=12)

# 设置刻度字体大小并旋转 x 轴标签
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 添加图例
plt.legend(fontsize=12)

# 设置网格
plt.grid(True, linestyle='--', alpha=0.7)

# 调整布局以防止标签被裁剪
plt.tight_layout()

# 显示图表
plt.savefig("avg_comparison_ablation.jpg", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据来自表格的 Avg 行
methods = ['32-hid', '64-hid', '128-hid', '256-hid', '512-hid', '1-layer', '2-layer', '3-layer', '4-layer', '5-layer']
A = [90.35, 88.92, 88.92, 89.28, 89.28, 88.92, 90.58, 91.04, 91.18, 90.54]  # Accuracy
R = [78.68, 77.14, 83.14, 83.43, 81.87, 79.80, 83.85, 85.24, 84.55, 87.28]  # Recall
P = [94.57, 91.78, 86.10, 86.89, 89.36, 88.22, 89.49, 89.59, 89.93, 87.37]  # Precision
F = [84.54, 82.48, 84.35, 84.92, 84.13, 83.46, 86.24, 87.09, 86.83, 87.18]  # F1-score

# 设置浅色调风格
plt.style.use('seaborn-v0_8-pastel')  # 使用 seaborn 的浅色调风格
plt.figure(figsize=(12, 6))

# 绘制折线图，设置粗线
plt.plot(methods, A, label='Accuracy', linewidth=3, marker='o', markersize=8, color='#66b3ff')
plt.plot(methods, R, label='Recall', linewidth=3, marker='s', markersize=8, color='#ff9999')
plt.plot(methods, P, label='Precision', linewidth=3, marker='^', markersize=8, color='#99ff99')
plt.plot(methods, F, label='F1-score', linewidth=3, marker='d', markersize=8, color='#ffcc99')

# 设置图表标题和标签
plt.title('Comparison of Average Metrics Across Methods', fontsize=16, pad=15)
plt.xlabel('Methods', fontsize=12)
plt.ylabel('Percentage (%)', fontsize=12)

# 设置刻度字体大小并旋转 x 轴标签
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

# 添加图例
plt.legend(fontsize=12)

# 设置网格
plt.grid(True, linestyle='--', alpha=0.7)

# 调整布局以防止标签被裁剪
plt.tight_layout()

# 显示图表
plt.savefig("avg_comparison_ps.jpg", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据来自表格的 Avg 行
methods = ['Scheck', 'Osiris', 'Slither', 'Mythril', 'sFuzz', 'Confuz', 'SaferSC', 'Escort', 'SCGCN', 'IVD', 'TMP', 'CGE', 'AME', 'SMS', 'FUSION']
A = [54.68, 63.99, 70.50, 67.24, 44.34, 68.47, 68.20, 65.88, 70.60, 69.63, 74.33, 75.59, 77.35, 82.95, 92.57]  # Accuracy
R = [55.11, 51.16, 64.31, 62.46, 28.79, 67.75, 68.40, 68.87, 72.85, 71.86, 72.81, 73.87, 74.93, 78.81, 87.32]  # Recall
P = [45.49, 53.68, 71.28, 57.55, 29.63, 62.23, 68.70, 66.77, 71.98, 71.69, 73.29, 74.48, 75.66, 80.93, 91.58]  # Precision
F = [46.71, 50.32, 67.35, 58.28, 28.94, 60.16, 69.02, 67.40, 72.41, 71.53, 73.04, 74.17, 75.29, 79.83, 89.27]  # F1-score

# 设置浅色调风格
plt.style.use('seaborn-v0_8-pastel')  # 使用 seaborn 的浅色调风格
plt.figure(figsize=(14, 6))  # 增加宽度以适应更多方法

# 绘制折线图，设置粗线
plt.plot(methods, A, label='Accuracy', linewidth=3, marker='o', markersize=8, color='#66b3ff')
plt.plot(methods, R, label='Recall', linewidth=3, marker='s', markersize=8, color='#ff9999')
plt.plot(methods, P, label='Precision', linewidth=3, marker='^', markersize=8, color='#99ff99')
plt.plot(methods, F, label='F1-score', linewidth=3, marker='d', markersize=8, color='#ffcc99')

# 设置图表标题和标签
plt.title('Comparison of Average Metrics Across Methods', fontsize=16, pad=15)
plt.xlabel('Methods', fontsize=12)
plt.ylabel('Percentage (%)', fontsize=12)

# 设置刻度字体大小并旋转 x 轴标签
plt.xticks(rotation=45, fontsize=10, ha='right')  # ha='right' 优化标签对齐
plt.yticks(fontsize=10)

# 添加图例
plt.legend(fontsize=12)

# 设置网格
plt.grid(True, linestyle='--', alpha=0.7)

# 调整布局以防止标签被裁剪
plt.tight_layout()

# 显示图表
plt.savefig("avg_comparison.jpg", dpi=300)
plt.show()
